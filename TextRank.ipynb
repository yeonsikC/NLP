# %% [markdown]
# <a href="https://colab.research.google.com/github/yeonsikC/NLP/blob/master/TextRank.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install newspaper3k

# %%
from newspaper import Article

#크롤링할 url 주소 입력
url = 'http://v.media.daum.net/v/20170604205121164'
url = 'https://www.hankyung.com/society/article/2020062616417'
#언어가 한국어이므로 language='ko'로 설정
a = Article(url, language='ko')
a.download()
a.parse()
#기사 제목 가져오기
print(a.title)
#기사 내용 가져오기(150자)

print(a.text[:150])
# Out:
# [속보] 안산 유치원 '집단 식중독' 유증상자 1명 추가…총 44명
# 문재인 정부가 21번째 부동산 대책인 '6.17대책'을 내놨습니다. 규제지역을 확대하고 갭투자를 차단하기 위해 대출규제와 법인들의 투자를 규제하게 됩니다. 재건축 조합에 2년 거주의무를 부여한 것을 비롯해 투기수요를 차단하기 위해 삼성·잠실 일대에 토지거래허가구역을 지

# %%
print(a.text)
# Out:
# 문재인 정부가 21번째 부동산 대책인 '6.17대책'을 내놨습니다. 규제지역을 확대하고 갭투자를 차단하기 위해 대출규제와 법인들의 투자를 규제하게 됩니다. 재건축 조합에 2년 거주의무를 부여한 것을 비롯해 투기수요를 차단하기 위해 삼성·잠실 일대에 토지거래허가구역을 지정하기도 했습니다. 이 같은 조치에 일부 지역에서는 거래가 위축되고 대출한도가 줄면서 지역 주민들이 반발하고 있는 반면, 다른 지역에서는 집값이 신고가를 경신하는 등 되레 상승했습니다. 시장에서는 실수요자로 시장이 재편되고 민간택지에 대한 분양가 상한제까지 시행되면, 집값이 거품이 꺼질 것이라는 예측이 있습니다. 다른 한편에서는 사상 최저 금리에 따른 시중 유동성이 풍부한 상황입니다. 각종 규제에도 수도권 내 중저가 주택을 중심으로 집값이 오를 것이라는 전망도 있습니다. 하반기 집값은 오를까요 내릴까요?

# %%
url = 'https://namu.wiki/w/%EC%B6%94%EB%AF%B8%EC%95%A0'
#언어가 한국어이므로 language='ko'로 설정
a = Article(url, language='ko')
a.download()
a.parse()
#기사 제목 가져오기
print(a.title)
#기사 내용 가져오기(150자)

print(a.text[:150])
# Out:
# 1958년 경상북도 달성군 (1995년 대구광역시 로 편입.)에서 세탁소를 운영하는 부모 밑에서 2남 2녀 중 셋째이자 차녀 로 태어났다. 대구남산초등학교, 구남여자중학교 한양대학교 법정대학을 졸업하고, 1982년 제24회 사법시험에 합격하였다.1985년, 같은 대학의

# %%
print(a.text)
# Out:
# 1958년 경상북도 달성군 (1995년 대구광역시 로 편입.)에서 세탁소를 운영하는 부모 밑에서 2남 2녀 중 셋째이자 차녀 로 태어났다. 대구남산초등학교, 구남여자중학교 한양대학교 법정대학을 졸업하고, 1982년 제24회 사법시험에 합격하였다.1985년, 같은 대학의 캠퍼스 커플 이었던 # 서성환 변호사 [7] 와 7년간의 연애 끝에 결혼 하여 법조인 부부로 이름을 알렸다.서 변호사는 전라북도 정읍시 출신인데, 당시만 해도 경상도 지역감정 이 극심했던 때라 영남의 집에서 호남 사위 를 보는 일은 흔치 않았다. 물론 반대도 마찬가지. 게다가 서 변호사는 고등학생 때 당한 교통사고로 인해 다리에 장애가 있었다. 이에 추미애의 집안에서는 결혼을 반대하였지만, 추미애는 이를 무릅쓰고 결혼하였다. # 이러한 까닭에 언론에서는 추미애를 가리켜, 그리고 추미애 스스로도 ' 대구 의 딸, 호남 의 며느리'라고 부른다. 한편 김대중 전 대통령도 추미애를 정계에 영입한 이후 "호남 사람인 제가 대구 며느리를 얻었습니다. 고맙습니다"라고 말한 바 있다. # # 슬하에는 3명 [8] 의 자녀가 있다.정계 입문 전에는 춘천지방법원 인천지방법원 , 전주지방법원, 광주고등법원 등에서 판사로서 일했다. 판사 시절 추미애는 ‘까칠한 여성 판사’로 통했다고 한다. 당시는 군부 독재 정권 시기였는데, 수사 당국이 공안 정국을 등에 업고 구속영장을 남발할 때 ‘법적’으로 용납이 안 되면 기각하기 일쑤였다.한번은 구속영장이 기각됐다며 경찰서장이 한밤 중에 추미애 당시 판사에게 전화를 걸어와 “내일 다시 신청할 테니 꼭 발부해달라”며 신경질을 낸 일이 있었다. 추미애가 “영장청구권자는 검사인데 서장께서 왜 직접 전화를 하는가? 판사가 한번 결정해 외부로 나간 일은 번복할 수 없다”라고 응수했는데, 다음 날 법원장이 불러 “아버지 같은 경찰서장에게 도대체 뭐라 했길래 서장이 그리 화가 난 것이냐”라며 질책했다. 추미애로서는 아무리 생각해도 그냥 넘어갈 수는 없는 일이라고 생각하여 검찰 쪽으로 문
# ...

# %%
# jvm 관련 에러 발생 시, konlpy와 Jpype1의 버젼이 충돌나서 생기는 문제! 다음 버전 지정으로 쉽게 해결이 가능하다!
# !pip install jpype1==0.7.0

# %%
from newspaper import Article
from konlpy.tag import Kkma
from konlpy.tag import Okt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import normalize
import numpy as np

# %%
class SentenceTokenizer(object):
    
    def __init__(self):
        self.kkma = Kkma()
        self.okt = Okt()
        self.stopwords = ['중인', '만큼', '마찬가지', '꼬집었', "연합뉴스", "데일리", "동아일보", "중앙일보", "조선일보", "기자"
            , "아", "휴", "아이구", "아이쿠", "아이고", "어", "나", "우리", "저희", "따라", "의해", "을", "를", "에", "의", "가", ]
    
    def url2sentences(self, url):
        article = Article(url, language='ko')
        article.download()
        article.parse()
        sentences = self.kkma.sentences(article.text)
        for idx in range(0, len(sentences)):
            if len(sentences[idx]) <= 10:
                sentences[idx - 1] += (' ' + sentences[idx])
                sentences[idx] = ''
        return sentences

    def text2sentences(self, text):
        sentences = self.kkma.sentences(text)
        for idx in range(0, len(sentences)):
            if len(sentences[idx]) <= 10:
                sentences[idx - 1] += (' ' + sentences[idx])
                sentences[idx] = ''
        return sentences

    def get_nouns(self, sentences):
        nouns = []
        for sentence in sentences:
            if sentence is not '':
                #nouns.append(' '.join([noun for noun in mecab_nouns(str(sentence))
                nouns.append(' '.join([noun for noun in self.okt.nouns(str(sentence))
                                       if noun not in self.stopwords and len(noun) > 1]))
        return nouns

# %%
class GraphMatrix(object):

    def __init__(self):
        self.tfidf = TfidfVectorizer()
        self.cnt_vec = CountVectorizer()
        self.graph_sentence = []

    def build_sent_graph(self, sentence):
        tfidf_mat = self.tfidf.fit_transform(sentence).toarray()
        self.graph_sentence = np.dot(tfidf_mat, tfidf_mat.T)
        return self.graph_sentence

    def build_words_graph(self, sentence):
        cnt_vec_mat = normalize(self.cnt_vec.fit_transform(sentence).toarray().astype(float), axis=0)
        vocab = self.cnt_vec.vocabulary_
        return np.dot(cnt_vec_mat.T, cnt_vec_mat), {vocab[word] : word for word in vocab}

# %%
class Rank(object):
    def get_ranks(self, graph, d=0.85): # d = damping factor
        A = graph
        matrix_size = A.shape[0]
        for id in range(matrix_size):
            A[id, id] = 0 # diagonal 부분을 0으로
            link_sum = np.sum(A[:,id]) # A[:, id] = A[:][id]
            if link_sum != 0:
                A[:, id] /= link_sum
            A[:, id] *= -d
            A[id, id] = 1
            
        B = (1-d) * np.ones((matrix_size, 1))
        ranks = np.linalg.solve(A, B) # 연립방정식 Ax = b
        return {idx: r[0] for idx, r in enumerate(ranks)}

# %%
class TextRank(object):
    
    def __init__(self, text):
        self.sent_tokenize = SentenceTokenizer()
        if text[:5] in ('http:', 'https'):
            self.sentences = self.sent_tokenize.url2sentences(text)
        else:
            self.sentences = self.sent_tokenize.text2sentences(text)
        self.nouns = self.sent_tokenize.get_nouns(self.sentences)
        self.graph_matrix = GraphMatrix()
        self.sent_graph = self.graph_matrix.build_sent_graph(self.nouns)
        self.words_graph, self.idx2word = self.graph_matrix.build_words_graph(self.nouns)
        self.rank = Rank()
        self.sent_rank_idx = self.rank.get_ranks(self.sent_graph)
        self.sorted_sent_rank_idx = sorted(self.sent_rank_idx, key=lambda k: self.sent_rank_idx[k], reverse=True)
        self.word_rank_idx = self.rank.get_ranks(self.words_graph)
        self.sorted_word_rank_idx = sorted(self.word_rank_idx, key=lambda k: self.word_rank_idx[k], reverse=True)

    def summarize(self, sent_num=3):
        summary = []
        index=[]
        for idx in self.sorted_sent_rank_idx[:sent_num]:
            index.append(idx)
        index.sort()
        for idx in index:
            summary.append(self.sentences[idx])
        return summary

    def keywords(self, word_num=10):
        rank = Rank()
        rank_idx = rank.get_ranks(self.words_graph)
        sorted_rank_idx = sorted(rank_idx, key=lambda k: rank_idx[k], reverse=True)
        keywords = []
        index=[]
        for idx in sorted_rank_idx[:word_num]:
            index.append(idx)
        #index.sort()
        for idx in index:
            keywords.append(self.idx2word[idx])
        return keywords

# %%
def mecab_nouns(word):
    import MeCab
    m = MeCab.Tagger()

    out = m.parse(word)

    output = []
    outLine = out.split("\n")

    for sentences in outLine[:-2]:
        sentence = sentences.split("\t")
        firstTag = sentence[1].split(",")[0]
        if firstTag[0] == "N":
            output.append(sentence[0])

    return(output)

# %%
def textrank(url):
    output = ''
    textrank = TextRank(url)
    for row in textrank.summarize(3):
        if len(output) == 0:
            output += row
        else:
            output += "\n"+row
    return output

# %%
# !pip install --upgrade pip
# Out:
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 20.0.2
#     Uninstalling pip-20.0.2:
#       Successfully uninstalled pip-20.0.2
# ERROR: Could not install packages due to an EnvironmentError: [WinError 5] 액세스가 거부되었습니다: 'C:\\Users\\yeonsik\\AppData\\Local\\Temp\\pip-uninstall-xfi0vsyk\\pip.exe'
# Consider using the `--user` option or check the permissions.

# %%
# !pip install C:\anaconda\Lib\site-packages\mecab_python-0.996_ko_0.9.2_msvc-cp37-cp37m-win_amd64.whl

# %%
import MeCab
m = MeCab.Tagger()
out = m.parse("아버지가방에들어가셨다.")
print(out)
# Out:
# 아버지	NNG,*,F,아버지,*,*,*,*
# 가	JKS,*,F,가,*,*,*,*
# 방	NNG,장소,T,방,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 들어가	VV,*,F,들어가,*,*,*,*
# 셨	EP+EP,*,T,셨,Inflect,EP,EP,시/EP/*+었/EP/*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# EOS

# %%
from konlpy.tag import Okt
okt = Okt()
okt.nouns("아버지가방에들어가셨다.")
# Out:
# ['아버지', '가방']

# %% [markdown]
# ### Mecab 이용

# %%
# %%time
url = "http://news.kbs.co.kr/news/view.do?ncd=4481856&ref=A"
textrank = TextRank(url)
for row in textrank.summarize(3):
    print(row)
    print()
print('keywords :',textrank.keywords())
# Out:
# 특히 확 진자 중 한 명이 어린이집 원장으로 확인돼 대전 시가 모든 어린이집을 대상으로 내일부터 다음 달 5일까지 휴 원 조치하기로 했습니다.
#
# 이 가운데 40대 여성은 대전시 대성동의 한 어린이집 원장으로 확인됐습니다.
#
# 또 대전지역의 모든 어린이집 1,204 곳을 대상으로 내일부터 다음 달 5일까지 휴 원조치 하기로 했습니다.
#
# keywords : ['대전', '신고', '차량', '진자', '방역', '확인', '검사', '외고', '방문', '통학']
# Wall time: 7.63 s

# %% [markdown]
# ### Okt 이용

# %%
# %%time
url = "http://news.kbs.co.kr/news/view.do?ncd=4481856&ref=A"
textrank = TextRank(url)
for row in textrank.summarize(3):
    print(row)
    print()
print('keywords :',textrank.keywords())
# Out:
# C:\Users\yeonsik\Anaconda3\lib\site-packages\konlpy\tag\_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')
# 특히 확 진자 중 한 명이 어린이집 원장으로 확인돼 대전 시가 모든 어린이집을 대상으로 내일부터 다음 달 5일까지 휴 원 조치하기로 했습니다.
#
# 또 대전지역의 모든 어린이집 1,204 곳을 대상으로 내일부터 다음 달 5일까지 휴 원조치 하기로 했습니다.
#
# 방역당국은 해당 차량을 이용한 대전 외고 학생 17명을 대상으로 검사를 진행해 이 중 15명은 음성으로 나왔고, 2명은 검사결과를 기다리는 중이며, 대전 대신고는 5명에 대해 검사를 진행 중입니다.
#
# keywords : ['대전', '진자', '차량', '대신고', '방역', '확인', '검사', '외고', '대해', '어제']
# Wall time: 1.02 s

# %% [markdown]
# # 서울과기대 민원데이터 적용

# %%
import pandas as pd
path = "C:/Users/yeonsik/Desktop/"
file_name = "서울과학기술대학교_홈페이지_온라인민원_착수보고회대비_190814.xlsx"
data = pd.read_excel(path+file_name)
data.head()
# Out:
#    연번  상태                    제목  \
# 0   1  30         능력향상장학금 관련 문의
# 1   2  10            졸업생 영문명 변경
# 2   3  10         복학 수강신청 질문입니다
# 3   4  30  BEAR 프로그램 관련 질문드립니다.
# 4   5  30            휴학생 웹메일 중지
#
#                                                  문의   \
# 0  안녕하세요 건축학부 건축학전공 재학중인 2학년 오다찬입니다. <br />능력향상 장...
# 1  안녕하세요,<br /><br />해외에 증명서류를 전달할 일이 있어 영문 이름으로 ...
# 2  제가 1학기때 1년 휴학신청을 한 상황입니다<br />2019.08.26 ~ 08....
# 3  안녕하세요.<br />기계자동차공학과에 재학중인 이정훈이라고 합니다.<br />과 ...
# 4  현재 군휴학 중인  휴학생입니다. 학교 웹메일을 확인할 일이 생겨서 포털 로그인을 ...
#
#                           등록일       답변부서  \
# 0  2019/08/11 21:46:06.000000      학생지원과
# 1  2019/08/11 12:30:42.000000        NaN
# 2  2019/08/10 19:22:13.000000        NaN
# 3  2019/08/10 18:09:18.000000  기계·자동차공학과
# 4  2019/08/10 10:21:41.000000      정보전산원
#
#                                                 답변내용
# 0  그렇습니다.   하반기에 신청할 때는 2019학년도 1학기 성적 기준으로만 신청이 ...
# 1                                                NaN
# ...

# %% [markdown]
# ## 최근 게시판 1000건만

# %%
data1000 = data.iloc[:1000,:]
data1000.head()
# Out:
#    연번  상태                    제목  \
# 0   1  30         능력향상장학금 관련 문의
# 1   2  10            졸업생 영문명 변경
# 2   3  10         복학 수강신청 질문입니다
# 3   4  30  BEAR 프로그램 관련 질문드립니다.
# 4   5  30            휴학생 웹메일 중지
#
#                                                  문의   \
# 0  안녕하세요 건축학부 건축학전공 재학중인 2학년 오다찬입니다. <br />능력향상 장...
# 1  안녕하세요,<br /><br />해외에 증명서류를 전달할 일이 있어 영문 이름으로 ...
# 2  제가 1학기때 1년 휴학신청을 한 상황입니다<br />2019.08.26 ~ 08....
# 3  안녕하세요.<br />기계자동차공학과에 재학중인 이정훈이라고 합니다.<br />과 ...
# 4  현재 군휴학 중인  휴학생입니다. 학교 웹메일을 확인할 일이 생겨서 포털 로그인을 ...
#
#                           등록일       답변부서  \
# 0  2019/08/11 21:46:06.000000      학생지원과
# 1  2019/08/11 12:30:42.000000        NaN
# 2  2019/08/10 19:22:13.000000        NaN
# 3  2019/08/10 18:09:18.000000  기계·자동차공학과
# 4  2019/08/10 10:21:41.000000      정보전산원
#
#                                                 답변내용
# 0  그렇습니다.   하반기에 신청할 때는 2019학년도 1학기 성적 기준으로만 신청이 ...
# 1                                                NaN
# ...

# %% [markdown]
# ## br태그 -> 띄어쓰기로 변환

# %%
# %%time
from tqdm import tqdm

result_questions = []
result_answers = []

questions = data1000['문의 ']
answers = data1000['답변내용']
for i in tqdm(range(len(data1000))):
    try:
        result_questions.append(textrank(questions[i].replace("<br />", " ")))
    except:
        result_questions.append("요약할 수 없음.")
    
    try:
        result_answers.append(textrank(answers[i].replace("<br />", " ")))
    except:
        result_answers.append("요약할 수 없음.")
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1000/1000 [03:37<00:00,  4.60it/s]
# Wall time: 3min 37s

# %%
result_answers
# Out:
# ['하반기에 신청할 때는 2019 학년도 1 학기 성적 기준으로만 신청이 가능합니다.\n다만, 내년부터 는 장학금관리지침이 개정되어 능력 향상 장학금이 없어 집니다.',
#  '요약할 수 없음.',
#  '요약할 수 없음.',
#  '안녕 하세요, 기계공학 프로그램 학과 사무실입니다.\n1. 기계자동차공학과 기계 프로그램은 여러 가지 사정으로 현재 BEAR 프로그램에 참여하고 있지 않습니다.\n2. BEAR 프로그램에 참여하는 다른 학과나 프로그램에서 진행하는 특강의 참여는 해당 학과나 프로그램에 문의 부탁 드립니다.',
#  '확인 결과 장기간 미사용으로 인하여 중지된 상태이고 현재 정상상태로 변경하여서 사용이 가능합니다.\n웹 메일 시스템 교체 (2019.7 .1 )에 따라서 비밀번호가 초기화가 되었습니다.\n포털에 연결된 계정이면 생년월일 6 자리 + !@# = ID 자릿수( 글자수) 예) 생년 월일 : 910101, 이메일 test@seoultech .ac .kr, 이메일 ID : test 초기 비밀번호 : 910101!@ #4 예) 생년 월일 : 760306, 이메일 apple@seoultech .ac .kr, 이메일 ID : apple 초기 비밀번호 : 760306!@ #5 위와 같이 접속하시어 변경 후 사용하시면 되겠습니다.',
#  '요약할 수 없음.',
#  '요약할 수 없음.',
#  '정보 인프라 팀입니다.\n그리고 메일에 연락처( 휴대번호) 가 등록된 경우에는 웹 메일 (https: //mail .seoultech .ac .kr) 의 비밀번호 찾기 기능을 이용하셔도 됩니다.',
#  '요약할 수 없음.',
#  '요약할 수 없음.',
#  '정보 인프라 팀입니다.\n그리고 메일에 연락처( 휴대번호) 가 등록된 경우에는 웹 메일 (https: //mail .seoultech .ac .kr) 의 비밀번호 찾기 기능을 이용하셔도 됩니다.',
# ...

# %%
data1000['문의_요약'] = result_questions
result_questions1 = [result.split("\n")[0] for result in result_questions]
result_questions1
data1000['문의_요약_첫문장'] = result_questions1
data1000['답변_요약'] = result_answers
# Out:
# C:\Users\yeonsik\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\yeonsik\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\yeonsik\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
data1000.to_excel(path+'200630_서울과기대_게시판데이터_TextRank_Okt.xlsx', index=None)
# Out:
# C:\Users\yeonsik\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:931: UserWarning: Ignoring URL 'http://www.seoultech.ac.kr/service/sccenter/qna/?do=commonview&searchtext=&searchtype=1&nowpage=1&bnum=3608&bidx=419002&qidx=3608&cate=10&allboard=false&nowpage=1%3cbr%20/%3e%3cbr%20/%3e위%20주소의%20복학%20Q&A에%20보면,%20복학관련%205번째%20문단에,%3cbr%20/%3e%20*%20복학원%20제출%20이후에는%20학적%20조회%20화면%20하단에%20'2015.00.00.에%20군복학이%20접수되었습니다.'%20메세지가%20뜹니다.%3cbr%20/%3e라고%20뜬다고%20하는%20데,%20저는%20'학적조회'화면에%20없어서%20문의드립니다.%3cbr%20/%3e%3cbr%20/%3e복학신청기간에,%20접수해서%20'담당자%20승인%20대기'라고%20뜨긴%20했지만,%3cbr%20/%3e혹여나%20'수강신청'이%20안되거나%20복학을%20못할%20수%20있을까봐%20걱정이%20되서요..%3cbr%20/%3e(장바구니%20신청은%20휴학생신분으로%20했습니다.)%3cbr%20/%3e%3cbr%20/%3e수강신청%20후,%20등록금을%20납부해야%20'재학생'으로%20바뀐다는%20것은%20숙지하고%20있습니다.%3cbr%20/%3e다만,%20제%20복학신청이%20제대로%20접수되었는%20지%20걱정되서%20이렇게%20문의드립니다.%3cbr%20/%3e%3cbr%20/%3e' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))

# %%
data1000['문의_요약_첫문장'] = result_questions1
data1000.to_excel(path+'서울과기대_게시판데이터_TextRank_첫문장만.xlsx', index=None)
# Out:
# C:\Users\yeonsik\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## test

# %%
textrank("https://www.hankyung.com/international/article/2020063031827")
# Out:
# '상무부는 29일( 현지시간) 윌버 로스 장관 명의의 성명을 통해 중국의 홍 콩 국가보안법 처리와 관련해 이같이 밝혔다.\n로스 장관은 " 홍 콩 보안법 제정으로 인해 민감한 미국의 기술이 중국 인민 해방군이나 국가안전 보위 부로 전용될 위험이 커졌다 "며 " 이런 위협으로 인해 미국이 홍 콩에 대한 특별 지위를 철회하게 됐다" 고 성명에서 말했다.\n'
